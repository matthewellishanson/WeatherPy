# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# Set wrapper
settings = {"units": "metric", "appid": api_key}

# %%
# set up list to hold data, set index to 0
data = []
i = 0


# Loop through cities to request data from owm for each, with exception handling for cities not found in owm api
for city in cities:
    query_url = f"{url}appid={api_key}&q={city}"
    
    try:
        response = owm.get_current(city, **settings)
        data.append(response)
    
        print(f'Processing Record {i} of {len(cities)} | {city}')
        i += 1

    except:
        print('City not found.')
        i += 1
# Out:
# Processing Record 0 of 602 | yuksekova
# Processing Record 1 of 602 | nikolskoye
# Processing Record 2 of 602 | suntar
# Processing Record 3 of 602 | albany
# Processing Record 4 of 602 | hobart
# Processing Record 5 of 602 | faanui
# Processing Record 6 of 602 | vaini
# Processing Record 7 of 602 | qaanaaq
# Processing Record 8 of 602 | narsaq
# Processing Record 9 of 602 | avarua
# Processing Record 10 of 602 | severo-kurilsk
# Processing Record 11 of 602 | torbay
# Processing Record 12 of 602 | port blair
# City not found.
# Processing Record 14 of 602 | kapaa
# Processing Record 15 of 602 | chokurdakh
# Processing Record 16 of 602 | east london
# Processing Record 17 of 602 | tuktoyaktuk
# Processing Record 18 of 602 | hamilton
# Processing Record 19 of 602 | brokopondo
# Processing Record 20 of 602 | barrow
# Processing Record 21 of 602 | vao
# Processing Record 22 of 602 | atuona
# Processing Record 23 of 602 | kruisfontein
# Processing Record 24 of 602 | bredasdorp
# Processing Record 25 of 602 | pangnirtung
# Processing Record 26 of 602 | ogbomosho
# Processing Record 27 of 602 | pangani
# City not found.
# Processing Record 29 of 602 | cape town
# Processing Record 30 of 602 | bilibino
# Processing Record 31 of 602 | port alfred
# Processing Record 32 of 602 | ancud
# Processing Record 33 of 602 | faya
# Processing Record 34 of 602 | buala
# Processing Record 35 of 602 | paciran
# Processing Record 36 of 602 | ribeira grande
# Processing Record 37 of 602 | gigmoto
# Processing Record 38 of 602 | busselton
# City not found.
# City not found.
# City not found.
# Processing Record 42 of 602 | mehamn
# Processing Record 43 of 602 | kaura namoda
# Processing Record 44 of 602 | dikson
# Processing Record 45 of 602 | shingu
# Processing Record 46 of 602 | ushuaia
# Processing Record 47 of 602 | kloulklubed
# Processing Record 48 of 602 | longyearbyen
# Processing Record 49 of 602 | saint-philippe
# Processing Record 50 of 602 | souillac
# Processing Record 51 of 602 | takestan
# City not found.
# Processing Record 53 of 602 | carnarvon
# Processing Record 54 of 602 | atar
# Processing Record 55 of 602 | yellowknife
# Processing Record 56 of 602 | ibra
# City not found.
# City not found.
# Processing Record 59 of 602 | chapais
# Processing Record 60 of 602 | sobolevo
# Processing Record 61 of 602 | huarmey
# City not found.
# Processing Record 63 of 602 | borzya
# Processing Record 64 of 602 | iqaluit
# Processing Record 65 of 602 | aswan
# City not found.
# City not found.
# Processing Record 68 of 602 | yining
# City not found.
# Processing Record 70 of 602 | bhag
# Processing Record 71 of 602 | kenai
# Processing Record 72 of 602 | vila franca do campo
# Processing Record 73 of 602 | minsk
# Processing Record 74 of 602 | bethel
# Processing Record 75 of 602 | kobelyaky
# Processing Record 76 of 602 | mataura
# Processing Record 77 of 602 | luderitz
# Processing Record 78 of 602 | yulara
# Processing Record 79 of 602 | lebu
# Processing Record 80 of 602 | jamestown
# Processing Record 81 of 602 | kholodnyy
# Processing Record 82 of 602 | vestmanna
# Processing Record 83 of 602 | hithadhoo
# Processing Record 84 of 602 | puerto ayora
# City not found.
# Processing Record 86 of 602 | college
# Processing Record 87 of 602 | muisne
# Processing Record 88 of 602 | burgos
# Processing Record 89 of 602 | klaksvik
# City not found.
# Processing Record 91 of 602 | new norfolk
# Processing Record 92 of 602 | saskylakh
# City not found.
# Processing Record 94 of 602 | kodiak
# City not found.
# Processing Record 96 of 602 | siderno
# Processing Record 97 of 602 | glamoc
# Processing Record 98 of 602 | mogadouro
# Processing Record 99 of 602 | hami
# Processing Record 100 of 602 | nome
# Processing Record 101 of 602 | arraial do cabo
# Processing Record 102 of 602 | newnan
# Processing Record 103 of 602 | mahebourg
# Processing Record 104 of 602 | rikitea
# Processing Record 105 of 602 | hermanus
# Processing Record 106 of 602 | tasiilaq
# Processing Record 107 of 602 | georgetown
# City not found.
# Processing Record 109 of 602 | pisco
# Processing Record 110 of 602 | salvador
# Processing Record 111 of 602 | muzhi
# Processing Record 112 of 602 | matamoros
# Processing Record 113 of 602 | kununurra
# Processing Record 114 of 602 | jalandhar
# Processing Record 115 of 602 | prince rupert
# Processing Record 116 of 602 | wohlen
# Processing Record 117 of 602 | laguna
# Processing Record 118 of 602 | mount gambier
# Processing Record 119 of 602 | carauari
# Processing Record 120 of 602 | bluff
# Processing Record 121 of 602 | rio grande
# Processing Record 122 of 602 | naro
# Processing Record 123 of 602 | boguchany
# Processing Record 124 of 602 | orumiyeh
# Processing Record 125 of 602 | nanortalik
# Processing Record 126 of 602 | lorengau
# Processing Record 127 of 602 | locri
# Processing Record 128 of 602 | anadyr
# Processing Record 129 of 602 | vestmannaeyjar
# Processing Record 130 of 602 | victoria
# Processing Record 131 of 602 | zhireken
# City not found.
# Processing Record 133 of 602 | nishihara
# Processing Record 134 of 602 | aykhal
# Processing Record 135 of 602 | batagay
# Processing Record 136 of 602 | saldanha
# Processing Record 137 of 602 | mendeleyevsk
# Processing Record 138 of 602 | touros
# Processing Record 139 of 602 | adrar
# Processing Record 140 of 602 | muros
# Processing Record 141 of 602 | punta arenas
# Processing Record 142 of 602 | urengoy
# Processing Record 143 of 602 | kavieng
# Processing Record 144 of 602 | terrace bay
# Processing Record 145 of 602 | la ronge
# Processing Record 146 of 602 | manggar
# Processing Record 147 of 602 | tuatapere
# Processing Record 148 of 602 | samarai
# Processing Record 149 of 602 | norman wells
# Processing Record 150 of 602 | hobyo
# Processing Record 151 of 602 | okha
# Processing Record 152 of 602 | upernavik
# Processing Record 153 of 602 | inhambane
# Processing Record 154 of 602 | nador
# Processing Record 155 of 602 | guerrero negro
# Processing Record 156 of 602 | gold coast
# Processing Record 157 of 602 | jacqueville
# Processing Record 158 of 602 | tiksi
# Processing Record 159 of 602 | ponta delgada
# City not found.
# Processing Record 161 of 602 | chuy
# Processing Record 162 of 602 | chicama
# Processing Record 163 of 602 | tarko-sale
# Processing Record 164 of 602 | kasongo-lunda
# Processing Record 165 of 602 | maniwaki
# Processing Record 166 of 602 | dombarovskiy
# Processing Record 167 of 602 | coihaique
# Processing Record 168 of 602 | wanxian
# Processing Record 169 of 602 | emerald
# Processing Record 170 of 602 | tommot
# City not found.
# Processing Record 172 of 602 | saint george
# Processing Record 173 of 602 | ikwiriri
# Processing Record 174 of 602 | husavik
# Processing Record 175 of 602 | boshnyakovo
# Processing Record 176 of 602 | biak
# Processing Record 177 of 602 | coihueco
# Processing Record 178 of 602 | tacuarembo
# Processing Record 179 of 602 | butaritari
# Processing Record 180 of 602 | kitimat
# Processing Record 181 of 602 | ilulissat
# Processing Record 182 of 602 | jalu
# Processing Record 183 of 602 | khatanga
# Processing Record 184 of 602 | pyshchug
# Processing Record 185 of 602 | luganville
# Processing Record 186 of 602 | aklavik
# Processing Record 187 of 602 | cherskiy
# Processing Record 188 of 602 | alofi
# City not found.
# Processing Record 190 of 602 | shimoda
# City not found.
# Processing Record 192 of 602 | spearfish
# Processing Record 193 of 602 | namibe
# Processing Record 194 of 602 | kieta
# Processing Record 195 of 602 | butte
# Processing Record 196 of 602 | ust-kuyga
# Processing Record 197 of 602 | srandakan
# Processing Record 198 of 602 | sabzevar
# Processing Record 199 of 602 | pontianak
# Processing Record 200 of 602 | bosaso
# Processing Record 201 of 602 | katsuura
# City not found.
# Processing Record 203 of 602 | kropotkin
# Processing Record 204 of 602 | bathsheba
# Processing Record 205 of 602 | svetlogorsk
# Processing Record 206 of 602 | vaitape
# Processing Record 207 of 602 | castro
# Processing Record 208 of 602 | khasan
# Processing Record 209 of 602 | fort nelson
# Processing Record 210 of 602 | jiwani
# Processing Record 211 of 602 | te anau
# Processing Record 212 of 602 | san policarpo
# Processing Record 213 of 602 | san cristobal
# Processing Record 214 of 602 | tura
# Processing Record 215 of 602 | coquimbo
# Processing Record 216 of 602 | koch bihar
# Processing Record 217 of 602 | flin flon
# Processing Record 218 of 602 | port lincoln
# Processing Record 219 of 602 | codrington
# Processing Record 220 of 602 | livingstone
# Processing Record 221 of 602 | columbus
# Processing Record 222 of 602 | praia da vitoria
# Processing Record 223 of 602 | salalah
# Processing Record 224 of 602 | gorom-gorom
# Processing Record 225 of 602 | pekan
# Processing Record 226 of 602 | moerai
# City not found.
# Processing Record 228 of 602 | fortuna
# Processing Record 229 of 602 | ponta do sol
# Processing Record 230 of 602 | mecca
# Processing Record 231 of 602 | pirapora
# Processing Record 232 of 602 | biloela
# Processing Record 233 of 602 | tanete
# Processing Record 234 of 602 | burlington
# Processing Record 235 of 602 | san quintin
# Processing Record 236 of 602 | voyvozh
# Processing Record 237 of 602 | barcelos
# Processing Record 238 of 602 | provideniya
# Processing Record 239 of 602 | uyuni
# Processing Record 240 of 602 | vila velha
# Processing Record 241 of 602 | geraldton
# City not found.
# Processing Record 243 of 602 | quatre cocos
# Processing Record 244 of 602 | juneau
# City not found.
# Processing Record 246 of 602 | navoi
# Processing Record 247 of 602 | burnie
# Processing Record 248 of 602 | samana
# Processing Record 249 of 602 | sao filipe
# City not found.
# Processing Record 251 of 602 | parati
# Processing Record 252 of 602 | eyl
# Processing Record 253 of 602 | kalaleh
# Processing Record 254 of 602 | fairbanks
# Processing Record 255 of 602 | tupik
# Processing Record 256 of 602 | kaitangata
# Processing Record 257 of 602 | lavrentiya
# City not found.
# Processing Record 259 of 602 | qena
# Processing Record 260 of 602 | dingle
# Processing Record 261 of 602 | pevek
# Processing Record 262 of 602 | turayf
# Processing Record 263 of 602 | sale
# Processing Record 264 of 602 | apt
# Processing Record 265 of 602 | guanay
# City not found.
# Processing Record 267 of 602 | haines junction
# Processing Record 268 of 602 | cedar city
# Processing Record 269 of 602 | fare
# Processing Record 270 of 602 | naron
# Processing Record 271 of 602 | shirokiy
# City not found.
# Processing Record 273 of 602 | tucuman
# Processing Record 274 of 602 | kaeo
# Processing Record 275 of 602 | novyy urengoy
# Processing Record 276 of 602 | amazar
# Processing Record 277 of 602 | cristalina
# Processing Record 278 of 602 | coxim
# Processing Record 279 of 602 | sao joao da barra
# Processing Record 280 of 602 | port hedland
# City not found.
# Processing Record 282 of 602 | dulian
# Processing Record 283 of 602 | port elizabeth
# Processing Record 284 of 602 | klyuchi
# Processing Record 285 of 602 | kizukuri
# Processing Record 286 of 602 | iquitos
# City not found.
# Processing Record 288 of 602 | egvekinot
# Processing Record 289 of 602 | hilo
# City not found.
# Processing Record 291 of 602 | caravelas
# Processing Record 292 of 602 | ahipara
# Processing Record 293 of 602 | burns lake
# Processing Record 294 of 602 | linxia
# Processing Record 295 of 602 | havoysund
# Processing Record 296 of 602 | kavaratti
# Processing Record 297 of 602 | luanda
# Processing Record 298 of 602 | muroto
# Processing Record 299 of 602 | baraki barak
# City not found.
# Processing Record 301 of 602 | bhunya
# Processing Record 302 of 602 | constitucion
# Processing Record 303 of 602 | kundiawa
# Processing Record 304 of 602 | teplyk
# Processing Record 305 of 602 | abu samrah
# Processing Record 306 of 602 | tiznit
# Processing Record 307 of 602 | yenagoa
# Processing Record 308 of 602 | nadvoitsy
# Processing Record 309 of 602 | paragominas
# Processing Record 310 of 602 | naberera
# Processing Record 311 of 602 | jumla
# Processing Record 312 of 602 | mount isa
# Processing Record 313 of 602 | victoria point
# Processing Record 314 of 602 | usinsk
# Processing Record 315 of 602 | haapiti
# Processing Record 316 of 602 | pilar
# Processing Record 317 of 602 | tulsipur
# Processing Record 318 of 602 | wanganui
# Processing Record 319 of 602 | diu
# Processing Record 320 of 602 | constantine
# Processing Record 321 of 602 | kluczbork
# City not found.
# Processing Record 323 of 602 | oistins
# Processing Record 324 of 602 | tyup
# Processing Record 325 of 602 | bhatkal
# Processing Record 326 of 602 | bulawayo
# Processing Record 327 of 602 | karratha
# Processing Record 328 of 602 | sotnikovo
# Processing Record 329 of 602 | kikwit
# Processing Record 330 of 602 | mnogovershinnyy
# Processing Record 331 of 602 | shieli
# Processing Record 332 of 602 | pozega
# Processing Record 333 of 602 | katherine
# Processing Record 334 of 602 | hirara
# Processing Record 335 of 602 | leku
# Processing Record 336 of 602 | lazaro cardenas
# Processing Record 337 of 602 | pendleton
# Processing Record 338 of 602 | mezen
# Processing Record 339 of 602 | develi
# Processing Record 340 of 602 | airai
# Processing Record 341 of 602 | ximei
# Processing Record 342 of 602 | lata
# Processing Record 343 of 602 | litovko
# Processing Record 344 of 602 | turukhansk
# Processing Record 345 of 602 | villa maria
# Processing Record 346 of 602 | port hardy
# Processing Record 347 of 602 | leningradskiy
# Processing Record 348 of 602 | maragogi
# Processing Record 349 of 602 | dondo
# Processing Record 350 of 602 | yeppoon
# Processing Record 351 of 602 | gol
# Processing Record 352 of 602 | ulladulla
# Processing Record 353 of 602 | conde
# Processing Record 354 of 602 | thompson
# Processing Record 355 of 602 | simao
# Processing Record 356 of 602 | vanimo
# Processing Record 357 of 602 | saint anthony
# Processing Record 358 of 602 | byron bay
# Processing Record 359 of 602 | monrovia
# Processing Record 360 of 602 | seoul
# City not found.
# Processing Record 362 of 602 | novokayakent
# Processing Record 363 of 602 | zwedru
# City not found.
# Processing Record 365 of 602 | sungaipenuh
# Processing Record 366 of 602 | araouane
# Processing Record 367 of 602 | henties bay
# Processing Record 368 of 602 | karad
# Processing Record 369 of 602 | santa rita do passa quatro
# Processing Record 370 of 602 | trebisacce
# Processing Record 371 of 602 | arauca
# Processing Record 372 of 602 | mar del plata
# Processing Record 373 of 602 | kurumkan
# Processing Record 374 of 602 | humaita
# Processing Record 375 of 602 | galle
# Processing Record 376 of 602 | kutoarjo
# Processing Record 377 of 602 | waipawa
# Processing Record 378 of 602 | isabela
# City not found.
# Processing Record 380 of 602 | acapulco
# Processing Record 381 of 602 | abay
# Processing Record 382 of 602 | kingsport
# Processing Record 383 of 602 | inuvik
# Processing Record 384 of 602 | zlynka
# Processing Record 385 of 602 | natal
# Processing Record 386 of 602 | naze
# Processing Record 387 of 602 | mopti
# Processing Record 388 of 602 | semnan
# Processing Record 389 of 602 | rocha
# Processing Record 390 of 602 | roswell
# Processing Record 391 of 602 | esperance
# Processing Record 392 of 602 | sydney
# Processing Record 393 of 602 | rodrigues alves
# Processing Record 394 of 602 | tevriz
# Processing Record 395 of 602 | mayo
# Processing Record 396 of 602 | srednekolymsk
# Processing Record 397 of 602 | alice springs
# Processing Record 398 of 602 | sola
# City not found.
# Processing Record 400 of 602 | valley city
# Processing Record 401 of 602 | maxixe
# Processing Record 402 of 602 | necochea
# Processing Record 403 of 602 | riachao das neves
# Processing Record 404 of 602 | san pedro
# Processing Record 405 of 602 | belmonte
# Processing Record 406 of 602 | paita
# Processing Record 407 of 602 | bereda
# Processing Record 408 of 602 | ostrovnoy
# Processing Record 409 of 602 | djenne
# Processing Record 410 of 602 | padang
# Processing Record 411 of 602 | manzanillo
# Processing Record 412 of 602 | atkarsk
# Processing Record 413 of 602 | waddan
# Processing Record 414 of 602 | labytnangi
# Processing Record 415 of 602 | taoudenni
# City not found.
# Processing Record 417 of 602 | kahului
# Processing Record 418 of 602 | never
# Processing Record 419 of 602 | garissa
# Processing Record 420 of 602 | zhizdra
# Processing Record 421 of 602 | stroud
# Processing Record 422 of 602 | chara
# Processing Record 423 of 602 | kondinskoye
# Processing Record 424 of 602 | zyryanovsk
# Processing Record 425 of 602 | giyani
# Processing Record 426 of 602 | erzurum
# Processing Record 427 of 602 | antofagasta
# Processing Record 428 of 602 | hashtrud
# Processing Record 429 of 602 | crossville
# Processing Record 430 of 602 | vostok
# Processing Record 431 of 602 | kosh-agach
# Processing Record 432 of 602 | bara
# Processing Record 433 of 602 | pacific grove
# Processing Record 434 of 602 | kiama
# Processing Record 435 of 602 | talnakh
# Processing Record 436 of 602 | jeremie
# Processing Record 437 of 602 | forbes
# Processing Record 438 of 602 | slonim
# Processing Record 439 of 602 | lampa
# Processing Record 440 of 602 | pangody
# Processing Record 441 of 602 | nemuro
# City not found.
# Processing Record 443 of 602 | goderich
# City not found.
# City not found.
# City not found.
# Processing Record 447 of 602 | tolbazy
# City not found.
# Processing Record 449 of 602 | grand gaube
# City not found.
# Processing Record 451 of 602 | roebourne
# Processing Record 452 of 602 | saint-pierre
# Processing Record 453 of 602 | los llanos de aridane
# Processing Record 454 of 602 | skibbereen
# Processing Record 455 of 602 | ati
# Processing Record 456 of 602 | buin
# Processing Record 457 of 602 | mercedes
# Processing Record 458 of 602 | san patricio
# Processing Record 459 of 602 | escarcega
# City not found.
# City not found.
# Processing Record 462 of 602 | aksarka
# Processing Record 463 of 602 | acajutla
# Processing Record 464 of 602 | arlit
# Processing Record 465 of 602 | tarquinia
# Processing Record 466 of 602 | wingham
# Processing Record 467 of 602 | beyneu
# Processing Record 468 of 602 | clyde river
# Processing Record 469 of 602 | mashhad
# City not found.
# Processing Record 471 of 602 | bunia
# Processing Record 472 of 602 | sechura
# Processing Record 473 of 602 | vagay
# Processing Record 474 of 602 | mao
# Processing Record 475 of 602 | sur
# Processing Record 476 of 602 | bayan
# Processing Record 477 of 602 | severo-yeniseyskiy
# Processing Record 478 of 602 | altay
# Processing Record 479 of 602 | atocha
# Processing Record 480 of 602 | cayenne
# Processing Record 481 of 602 | gangtok
# City not found.
# Processing Record 483 of 602 | meulaboh
# Processing Record 484 of 602 | saint-paul
# Processing Record 485 of 602 | baft
# Processing Record 486 of 602 | kaabong
# Processing Record 487 of 602 | umea
# Processing Record 488 of 602 | khandyga
# Processing Record 489 of 602 | lasa
# Processing Record 490 of 602 | bacolod
# Processing Record 491 of 602 | comodoro rivadavia
# Processing Record 492 of 602 | azare
# Processing Record 493 of 602 | venice
# Processing Record 494 of 602 | sanica
# Processing Record 495 of 602 | flinders
# Processing Record 496 of 602 | portland
# Processing Record 497 of 602 | mkushi
# Processing Record 498 of 602 | sabang
# Processing Record 499 of 602 | mogocha
# Processing Record 500 of 602 | san andres del rabanedo
# Processing Record 501 of 602 | bom jesus
# Processing Record 502 of 602 | pochutla
# Processing Record 503 of 602 | sapa
# Processing Record 504 of 602 | alyangula
# Processing Record 505 of 602 | imperatriz
# Processing Record 506 of 602 | iraquara
# City not found.
# Processing Record 508 of 602 | carnot
# Processing Record 509 of 602 | oyem
# Processing Record 510 of 602 | kolvereid
# Processing Record 511 of 602 | rock springs
# Processing Record 512 of 602 | bogalusa
# Processing Record 513 of 602 | terekli-mekteb
# Processing Record 514 of 602 | chiang khong
# Processing Record 515 of 602 | changji
# Processing Record 516 of 602 | mekhe
# Processing Record 517 of 602 | angra dos reis
# Processing Record 518 of 602 | titisee-neustadt
# Processing Record 519 of 602 | zalegoshch
# Processing Record 520 of 602 | kenora
# Processing Record 521 of 602 | inzer
# Processing Record 522 of 602 | najran
# Processing Record 523 of 602 | songjianghe
# Processing Record 524 of 602 | paamiut
# City not found.
# City not found.
# Processing Record 527 of 602 | marica
# Processing Record 528 of 602 | matara
# City not found.
# Processing Record 530 of 602 | cabo san lucas
# Processing Record 531 of 602 | chongqing
# City not found.
# City not found.
# Processing Record 534 of 602 | wanning
# Processing Record 535 of 602 | margate
# Processing Record 536 of 602 | hovd
# Processing Record 537 of 602 | port macquarie
# Processing Record 538 of 602 | moba
# Processing Record 539 of 602 | batemans bay
# Processing Record 540 of 602 | cheremukhovo
# Processing Record 541 of 602 | zaysan
# Processing Record 542 of 602 | alta floresta
# City not found.
# Processing Record 544 of 602 | bandarbeyla
# Processing Record 545 of 602 | kurmanayevka
# Processing Record 546 of 602 | harper
# Processing Record 547 of 602 | aguimes
# Processing Record 548 of 602 | verkhnechusovskiye gorodki
# Processing Record 549 of 602 | opuwo
# City not found.
# Processing Record 551 of 602 | abu kamal
# Processing Record 552 of 602 | kanniyakumari
# Processing Record 553 of 602 | general roca
# Processing Record 554 of 602 | thinadhoo
# Processing Record 555 of 602 | chumikan
# Processing Record 556 of 602 | birao
# Processing Record 557 of 602 | gurlan
# Processing Record 558 of 602 | nenjiang
# Processing Record 559 of 602 | phalombe
# Processing Record 560 of 602 | xining
# Processing Record 561 of 602 | nakapiripirit
# Processing Record 562 of 602 | bulgan
# Processing Record 563 of 602 | carutapera
# Processing Record 564 of 602 | posse
# Processing Record 565 of 602 | nicoya
# Processing Record 566 of 602 | hammerfest
# Processing Record 567 of 602 | saint john
# City not found.
# Processing Record 569 of 602 | bambous virieux
# Processing Record 570 of 602 | nuuk
# Processing Record 571 of 602 | skjervoy
# Processing Record 572 of 602 | harindanga
# Processing Record 573 of 602 | arroio grande
# Processing Record 574 of 602 | ormskirk
# Processing Record 575 of 602 | mitchell
# Processing Record 576 of 602 | empangeni
# Processing Record 577 of 602 | lakes entrance
# Processing Record 578 of 602 | damghan
# Processing Record 579 of 602 | alekseyevsk
# Processing Record 580 of 602 | fukue
# City not found.
# Processing Record 582 of 602 | pokosnoye
# Processing Record 583 of 602 | myre
# Processing Record 584 of 602 | sambir
# Processing Record 585 of 602 | orillia
# Processing Record 586 of 602 | kolokani
# City not found.
# Processing Record 588 of 602 | bud
# Processing Record 589 of 602 | santa isabel do rio negro
# Processing Record 590 of 602 | gladstone
# Processing Record 591 of 602 | san angelo
# Processing Record 592 of 602 | asyut
# Processing Record 593 of 602 | liuhe
# Processing Record 594 of 602 | mangan
# Processing Record 595 of 602 | bogandinskiy
# City not found.
# Processing Record 597 of 602 | mahibadhoo
# Processing Record 598 of 602 | niort
# Processing Record 599 of 602 | puerto del rosario
# Processing Record 600 of 602 | porto novo
# Processing Record 601 of 602 | sisimiut

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe from data
cityweather = pd.DataFrame(data)

# Filter down to just the necessary columns
cityweather = cityweather[['name', 'coord', 'dt', 'id', 'main', 'clouds', 'wind']]
cityweather.head()
# Out:
#          name                           coord          dt       id  \
# 0   Yuksekova    {'lon': 44.29, 'lat': 37.57}  1554562800   296173
# 1  Nikolskoye     {'lon': 30.79, 'lat': 59.7}  1554568200   546105
# 2      Suntar   {'lon': 117.65, 'lat': 62.16}  1554568344  2015913
# 3      Albany   {'lon': -73.75, 'lat': 42.65}  1554568325  5106834
# 4      Hobart  {'lon': 147.33, 'lat': -42.88}  1554568154  2163355
#
#                                                 main       clouds  \
# 0  {'temp': 13, 'pressure': 1013, 'humidity': 47,...  {'all': 20}
# 1  {'temp': 10.91, 'pressure': 1023, 'humidity': ...   {'all': 0}
# 2  {'temp': -7.51, 'pressure': 1022.94, 'humidity...   {'all': 0}
# 3  {'temp': 7.91, 'pressure': 1023, 'humidity': 6...  {'all': 90}
# 4  {'temp': 9.31, 'pressure': 1014, 'humidity': 7...   {'all': 0}
#
#                               wind
# 0       {'speed': 7.2, 'deg': 220}
# 1         {'speed': 5, 'deg': 100}
# 2  {'speed': 1.46, 'deg': 284.504}
# 3  {'speed': 2.66, 'deg': 295.004}
# 4       {'speed': 3.6, 'deg': 330}

# %%
# Many of the fields are actually dictionary values grouped under a single parent column in the dataframe
# Extract the dictionaries containing temp, wind speed, humidity, cloud % and latitude, then set each to lists
coord = cityweather['coord'].tolist()
main = cityweather['main'].tolist()
clouds = cityweather['clouds'].tolist()
wind = cityweather['wind'].tolist()

# Create dataframes from those lists
coord_df = pd.DataFrame(coord)
main_df = pd.DataFrame(main)
clouds_df = pd.DataFrame(clouds)
wind_df = pd.DataFrame(wind)

# prep original dataframe to be compatible with merges with the new DFs by creating a list, setting
mergeready = cityweather.loc[:, ['name', 'dt']]

# merge new DFs with original

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
